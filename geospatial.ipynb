# %%
import leafmap.maplibregl as leafmap

# %%
m = leafmap.Map(style="liberty", projection="globe")

# %%
m
# Out:
# Html(children=[<leafmap.maplibregl.Map object at 0x338e43f20>, Card(children=[Btn(children=[Icon(children=['md…
